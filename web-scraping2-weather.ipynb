# %%
import requests as rq
from bs4 import BeautifulSoup

# %%
page = rq.get('http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168') #use this because their website isn't working 
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
seven_day = soup.find(id='seven-day-forecast-body')
forecast_items = seven_day.find_all(class_="tombstone-container")
forecast_items[0]
# Out:
# <div class="tombstone-container">
# <p class="period-name">This<br/>Afternoon</p>
# <p><img alt="This Afternoon: Sunny, with a high near 74. Light west northwest wind. " class="forecast-icon" src="newimages/medium/few.png" title="This Afternoon: Sunny, with a high near 74. Light west northwest wind. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 74 °F</p></div>

# %%
this_afternoon = forecast_items[0]
print(this_afternoon.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   This
#   <br/>
#   Afternoon
#  </p>
#  <p>
#   <img alt="This Afternoon: Sunny, with a high near 74. Light west northwest wind. " class="forecast-icon" src="newimages/medium/few.png" title="This Afternoon: Sunny, with a high near 74. Light west northwest wind. "/>
#  </p>
#  <p class="short-desc">
#   Sunny
#  </p>
#  <p class="temp temp-high">
#   High: 74 °F
#  </p>
# </div>

# %%
period = this_afternoon.find(class_="period-name").get_text()
short_desc = this_afternoon.find(class_="short-desc").get_text()
temp = this_afternoon.find(class_="temp").get_text()
print(period)
print(short_desc)
print(temp)
# Out:
# ThisAfternoon
# Sunny
# High: 74 °F

# %% [markdown]
# <h4>Now, we can extract the title attribute from the img tag. To do this, we just treat the BeautifulSoup object like a dictionary, and pass in the attribute we want as a key:

# %%
img = this_afternoon.find('img')
desc = img['title']
print(desc)
# Out:
# This Afternoon: Sunny, with a high near 74. Light west northwest wind.

# %% [markdown]
# <h3> extracting all the info at once

# %%
period_tags = seven_day.select(".tombstone-container .period-name") #remember from web dev when declaring a class in css uses .class 
[period_tag.get_text() for period_tag in period_tags] #period_tags is periods in tutorial
# Out:
# ['ThisAfternoon',
#  'Tonight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday']

# %%
#apply the same technique to get the other fields which are from above you can see: first p tag is image with title, 2nd is short_desc, 3rd is temp
descs = [desc['title'] for desc in seven_day.select(".tombstone-container img")]
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [temp.get_text() for temp in seven_day.select(".tombstone-container .temp")]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['Sunny', 'Mostly Clear', 'Sunny', 'Partly Cloudy', 'Mostly Sunny', 'Partly Cloudy', 'Mostly Sunny', 'Mostly Clear', 'Sunny']
# ['High: 74 °F', 'Low: 53 °F', 'High: 74 °F', 'Low: 51 °F', 'High: 70 °F', 'Low: 52 °F', 'High: 74 °F', 'Low: 54 °F', 'High: 77 °F']
# ['This Afternoon: Sunny, with a high near 74. Light west northwest wind. ', 'Tonight: Mostly clear, with a low around 53. West wind 3 to 7 mph. ', 'Thursday: Sunny, with a high near 74. Calm wind becoming west 5 to 7 mph in the afternoon. ', 'Thursday Night: Partly cloudy, with a low around 51. West wind 5 to 10 mph becoming light west southwest  after midnight. ', 'Friday: Mostly sunny, with a high near 70. Calm wind becoming west 5 to 8 mph in the afternoon. ', 'Friday Night: Partly cloudy, with a low around 52.', 'Saturday: Mostly sunny, with a high near 74.', 'Saturday Night: Mostly clear, with a low around 54.', 'Sunday: Sunny, with a high near 77.']

# %%
#from tutorial
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['Sunny', 'Mostly Clear', 'Sunny', 'Partly Cloudy', 'Mostly Sunny', 'Partly Cloudy', 'Mostly Sunny', 'Mostly Clear', 'Sunny']
# ['High: 74 °F', 'Low: 53 °F', 'High: 74 °F', 'Low: 51 °F', 'High: 70 °F', 'Low: 52 °F', 'High: 74 °F', 'Low: 54 °F', 'High: 77 °F']
# ['This Afternoon: Sunny, with a high near 74. Light west northwest wind. ', 'Tonight: Mostly clear, with a low around 53. West wind 3 to 7 mph. ', 'Thursday: Sunny, with a high near 74. Calm wind becoming west 5 to 7 mph in the afternoon. ', 'Thursday Night: Partly cloudy, with a low around 51. West wind 5 to 10 mph becoming light west southwest  after midnight. ', 'Friday: Mostly sunny, with a high near 70. Calm wind becoming west 5 to 8 mph in the afternoon. ', 'Friday Night: Partly cloudy, with a low around 52.', 'Saturday: Mostly sunny, with a high near 74.', 'Saturday Night: Mostly clear, with a low around 54.', 'Sunday: Sunny, with a high near 77.']

# %% [markdown]
# <h3> Combining our data into a Pandas Dataframe

# %%
import pandas as pd

# %%
weather = pd.DataFrame({
    "period": period_tags, #this is period in the tutorial
    "short_desc": short_descs,
    "temp": temps,
    "descs": descs
})
weather
# Out:
#                   period     short_desc         temp  \
# 0  [This, [], Afternoon]          Sunny  High: 74 °F
# 1      [Tonight, [], []]   Mostly Clear   Low: 53 °F
# 2     [Thursday, [], []]          Sunny  High: 74 °F
# 3  [Thursday, [], Night]  Partly Cloudy   Low: 51 °F
# 4       [Friday, [], []]   Mostly Sunny  High: 70 °F
# 5    [Friday, [], Night]  Partly Cloudy   Low: 52 °F
# 6     [Saturday, [], []]   Mostly Sunny  High: 74 °F
# 7  [Saturday, [], Night]   Mostly Clear   Low: 54 °F
# 8       [Sunday, [], []]          Sunny  High: 77 °F
#
#                                                descs
# 0  This Afternoon: Sunny, with a high near 74. Li...
# 1  Tonight: Mostly clear, with a low around 53. W...
# 2  Thursday: Sunny, with a high near 74. Calm win...
# 3  Thursday Night: Partly cloudy, with a low arou...
# 4  Friday: Mostly sunny, with a high near 70. Cal...
# 5  Friday Night: Partly cloudy, with a low around...
# 6       Saturday: Mostly sunny, with a high near 74.
# ...

# %% [markdown]
# <h4> We can now do some analysis on the data. For example, we can use a regular expression and the Series.str.extract method to pull out the numeric temperature values:

# %%
#time for some analysis 
temp_nums = weather["temp"].str.extract("(?P<temp_num>\d+)", expand=False) #temp_nums = weather["temp"].str.extract("(?P<temp_num>\d)", expand=False)
weather['temp_num'] = temp_nums.astype('int')
temp_nums
# Out:
# 0    74
# 1    53
# 2    74
# 3    51
# 4    70
# 5    52
# 6    74
# 7    54
# 8    77
# Name: temp_num, dtype: object

# %%
weather["temp_num"].mean()
# Out:
# 64.33333333333333

# %%
is_night = weather['temp'].str.contains("Low")
weather["is_night"] = is_night
is_night
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# Name: temp, dtype: bool

# %%
weather[is_night]
# Out:
#                   period     short_desc        temp  \
# 1      [Tonight, [], []]   Mostly Clear  Low: 53 °F
# 3  [Thursday, [], Night]  Partly Cloudy  Low: 51 °F
# 5    [Friday, [], Night]  Partly Cloudy  Low: 52 °F
# 7  [Saturday, [], Night]   Mostly Clear  Low: 54 °F
#
#                                                descs  is_night  temp_num
# 1  Tonight: Mostly clear, with a low around 53. W...      True        53
# 3  Thursday Night: Partly cloudy, with a low arou...      True        51
# 5  Friday Night: Partly cloudy, with a low around...      True        52
# 7  Saturday Night: Mostly clear, with a low aroun...      True        54

# %% [markdown]
# What Can I Do With Web Scraping?
#
# With web scraping, the biggest limitation is probably what you may do, not what you can do. With the right code, pretty much any data that’s on a public-facing website can be downloaded, filtered, and formatted with web scraping.
#
# Whether that’s allowed or even legal is another story, though.
#
# As we mentioned at the beginning of the article, it’s important to determine a website’s policy on web scraping before you attempt scraping it. If scraping is permitted, you should be sure to follow the best-practices outlined earlier in the article to make sure you aren’t overly taxing the website in question.
# Python Libraries for Web Scraping
#
#     requests — this critical library is needed to actually get the data from the web server onto your machine, and it contains some additional cool features like caching too.
#     Beautiful Soup 4 — This is the library we’ve used here, and it’s designed to make filtering data based on HTML tags straightforward.
#     lmxl — An HTML and XML parser that’s fast (and now, integrated with Beautiful Soup, too!)
#     Selenium — A web driver tool that’s useful when you need to get data from a website that the requests library can’t access, because it’s hidden behind things like login forms or mandatory mouse-clicks.
#     Scrapy — A full-on web scraping framework that might be overkill for one-off data analysis projects, but a good fit when scraping’s required for production projects, pipelines, etc.
#
#     If you want to learn more about any of the topics covered here, check out our interactive courses which you can start for free: Web Scraping in Python
